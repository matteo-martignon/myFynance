# %%
import pandas as pd

# %%
from datetime import datetime

now = datetime.utcnow().strftime("%Y%m%d%H%M%S")

# %%
pd.to_datetime(now)
# Out:
# Timestamp('2021-09-14 21:13:19')

# %%
path = "data/data.csv"

# %%
df = pd.read_csv(path, sep=";", parse_dates=["Data", "insert_date"])

# %%
df.columns
# Out:
# Index(['Data', 'Operazione', 'Dettagli', 'Conto o carta', 'Contabilizzazione',
#        'Categoria ', 'Valuta', 'Importo', 'Tipologia', 'Agente',
#        'Spesa Comune', 'insert_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1664 entries, 0 to 1663
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Data               1664 non-null   datetime64[ns]
#  1   Operazione         1476 non-null   object
#  2   Dettagli           1664 non-null   object
#  3   Conto o carta      1476 non-null   object
#  4   Contabilizzazione  1476 non-null   object
#  5   Categoria          1485 non-null   object
#  6   Valuta             1476 non-null   object
#  7   Importo            1664 non-null   object
#  8   Tipologia          1664 non-null   object
#  9   Agente             1664 non-null   object
#  10  Spesa Comune       317 non-null    object
#  11  insert_date        376 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(10)
# memory usage: 156.1+ KB

# %%
df.drop(columns=["Conto o carta", "Contabilizzazione", "Valuta"])
# Out:
#            Data                                         Operazione  \
# 0    2021-07-03                             Lafeltrinelli Internet
# 1    2021-06-03                                    Paypal *edt Srl
# 2    2021-05-03  Addebito Diretto Disposto A Favore Di FINDOMES...
# 3    2021-05-03              Investimento Previdenza Complementare
# 4    2021-03-03                       Sepa Direct Debit Superflash
# ...         ...                                                ...
# 1659 2021-03-17                                                NaN
# 1660 2021-03-15                                                NaN
# 1661 2021-06-03                                                NaN
# 1662 2021-07-03                                                NaN
# 1663 2021-07-03                                                NaN
#
#                                                Dettagli  \
# 0                               Lafeltrinelli Internet
# ...

# %%
df[df["Agente"] == "M"]
# Out:
#            Data                                         Operazione  \
# 0    2021-07-03                             Lafeltrinelli Internet
# 1    2021-06-03                                    Paypal *edt Srl
# 2    2021-05-03  Addebito Diretto Disposto A Favore Di FINDOMES...
# 3    2021-05-03              Investimento Previdenza Complementare
# 4    2021-03-03                       Sepa Direct Debit Superflash
# ...         ...                                                ...
# 1149 2021-03-05              Investimento Previdenza Complementare
# 1150 2021-03-03                       Sepa Direct Debit Superflash
# 1151 2021-03-01                       Sepa Direct Debit Superflash
# 1152 2021-02-28     Bonifico Disposto A Favore Di FEDERICO SPADARO
# 1153 2021-02-28                       Beu Tramite Internet Banking
#
#                                                Dettagli  \
# 0                               Lafeltrinelli Internet
# ...
